# %%
# %cd /kaggle/working
# !git clone https://github.com/fyj404/GaussionPro.git --recursive
# !pip install -q plyfile
# %cd GaussionPro
# !pip install ./submodules/diff-gaussian-rasterization
# !pip install ./submodules/simple-knn
# !pip install ./submodules/Propagation
# !wget -O pc_v7.zip https://huggingface.co/datasets/f2fa/3dgs-ue/resolve/main/pc_v7.zip
# !unzip pc_v7.zip
# Out:
# /kaggle/working
# Cloning into 'GaussionPro'...
# remote: Enumerating objects: 270, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 270 (delta 2), reused 4 (delta 2), pack-reused 261 (from 2)
# Receiving objects: 100% (270/270), 78.41 MiB | 19.94 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/kaggle/working/GaussionPro/submodules/diff-gaussian-rasterization'...
# remote: Enumerating objects: 329, done.
# remote: Total 329 (delta 0), reused 0 (delta 0), pack-reused 329 (from 1)
# Receiving objects: 100% (329/329), 111.68 KiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (216/216), done.
# ...

# %%
# !pip install open3d
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# ...

# %%
# !python train.py -s ./pc_v7 -m ./output/pc_v7 --eval --position_lr_init 0.000016 --scaling_lr 0.001 --percent_dense 0.0005 --iteration 50000
# !python render.py -m ./output/pc_v7
# !python metrics.py -m ./output/pc_v7
# Out:
# 2025-03-09 12:55:35.046762: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-09 12:55:35.242816: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-09 12:55:35.297686: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Optimizing ./output/pc_v7
# Output folder: ./output/pc_v7 [09/03 12:55:44]
# Reading camera 349/349 [09/03 12:55:44]
# Loading Training Cameras [09/03 12:55:44]
# Loading Test Cameras [09/03 12:55:50]
# Number of points at initialisation :  27089 [09/03 12:55:51]
# Training progress:  60%|█▏| 30000/50000 [48:46<35:10,  9.48it/s, Loss=0.0361134]
# ...

# %%
# %mkdir cost
# !python train.py -s ./pc_v7 -m ./output/pc_v7_2 --iteration 50000 --eval --flatten_loss --position_lr_init 0.000016 --scaling_lr 0.001 --percent_dense 0.0005  --normal_loss --depth_loss --propagation_interval 50 --depth_error_min_threshold 0.8 --depth_error_max_threshold 1.0  --patch_size 20 --lambda_l1_normal 0.001 --lambda_cos_normal 0.001 --propagated_iteration_begin 1000 --propagated_iteration_after 6000
# Out:
# 2025-03-09 14:26:40.040049: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-09 14:26:40.065580: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-09 14:26:40.072652: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Optimizing ./output/pc_v7_2
# Output folder: ./output/pc_v7_2 [09/03 14:26:42]
# Reading camera 349/349 [09/03 14:26:42]
# Loading Training Cameras [09/03 14:26:42]
# Loading Test Cameras [09/03 14:26:48]
# Number of points at initialisation :  27089 [09/03 14:26:48]
# ...

# %%
# !python render.py -m ./output/pc_v7_2
# !python metrics.py -m ./output/pc_v7_2
# Out:
# Looking for config file in ./output/pc_v7_2/cfg_args
# Config file found: ./output/pc_v7_2/cfg_args
# Rendering ./output/pc_v7_2
# Loading trained model at iteration 50000 [09/03 16:28:15]
# Reading camera 349/349 [09/03 16:28:15]
# Loading Training Cameras [09/03 16:28:15]
# Loading Test Cameras [09/03 16:28:21]
# ...
# Rendering progress: 100%|███████████████████████| 44/44 [00:26<00:00,  1.63it/s]
#
# Scene: ./output/pc_v7_2
# Method: ours_50000
# Metric evaluation progress: 100%|███████████████| 44/44 [01:18<00:00,  1.78s/it]
#   SSIM :    0.8827158
#   PSNR :   27.2394962
#   LPIPS:    0.1299344

# %%
# !zip -r output.zip ./output/
# !zip -r cost.zip ./cost/
# Out:
#   adding: output/ (stored 0%)
#   adding: output/pc_v7/ (stored 0%)
#   adding: output/pc_v7/point_cloud/ (stored 0%)
#   adding: output/pc_v7/point_cloud/iteration_30000/ (stored 0%)
#   adding: output/pc_v7/point_cloud/iteration_30000/point_cloud.ply (deflated 15%)
#   adding: output/pc_v7/point_cloud/iteration_50000/ (stored 0%)
#   adding: output/pc_v7/point_cloud/iteration_50000/point_cloud.ply (deflated 15%)
#   adding: output/pc_v7/cfg_args (deflated 29%)
#   adding: output/pc_v7/results.json (deflated 14%)
#   adding: output/pc_v7/train/ (stored 0%)
#   adding: output/pc_v7/train/ours_50000/ (stored 0%)
#   adding: output/pc_v7/train/ours_50000/render_normal/ (stored 0%)
#   adding: output/pc_v7/train/ours_50000/render_normal/00144.png (deflated 0%)
#   adding: output/pc_v7/train/ours_50000/render_normal/00166.png (deflated 0%)
#   adding: output/pc_v7/train/ours_50000/render_normal/00212.png (deflated 0%)
# ...
